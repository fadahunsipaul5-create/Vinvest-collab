# %%
API_KEY = '6d4bd60e237eae6df24af2c0189a10278154d4f2079dec475b7d15ca11baea04'
#instantiate query api
from sec_api import QueryApi
queryApi = QueryApi(api_key=API_KEY)

# %%
import pandas as pd

# %%
def get_filings(query):
  from_param = 0
  size_param = 200
  all_filings = []

  while True:
    query['from'] = from_param
    query['size'] = size_param

    response = queryApi.get_filings(query)
    filings = response['filings']

    if len(filings) == 0:
      break

    all_filings.extend(filings)

    from_param += size_param

  return pd.json_normalize(all_filings)

# %%
form_type_query  = 'formType:("10-K") AND NOT formType:("10-K/A", "10-Q/A", NT)'
ticker_query     = 'ticker:(AAPL)'
date_range_query = 'filedAt:[2020-01-01 TO 2025-03-15]'

lucene_query = f"{form_type_query} AND {ticker_query} AND {date_range_query}"

search_query = {
  "query": lucene_query,
  "from": "0",
  "size": "200",
  "sort": [{ "filedAt": { "order": "desc" } }]
}

filings = get_filings(search_query)

# %%
lucene_query
# Out:
# 'formType:("10-K") AND NOT formType:("10-K/A", "10-Q/A", NT) AND ticker:(AAPL) AND filedAt:[2020-01-01 TO 2025-03-15]'

# %%
search_query
# Out:
# {'query': 'formType:("10-K") AND NOT formType:("10-K/A", "10-Q/A", NT) AND ticker:(AAPL) AND filedAt:[2020-01-01 TO 2025-03-15]',
#  'from': 200,
#  'size': 200,
#  'sort': [{'filedAt': {'order': 'desc'}}]}

# %%
filings.head(20)
# Out:
#   ticker formType           accessionNo     cik     companyNameLong  \
# 0   AAPL     10-K  0000320193-24-000123  320193  Apple Inc. (Filer)
# 1   AAPL     10-K  0000320193-23-000106  320193  Apple Inc. (Filer)
# 2   AAPL     10-K  0000320193-22-000108  320193  Apple Inc. (Filer)
# 3   AAPL     10-K  0000320193-21-000105  320193  Apple Inc. (Filer)
# 4   AAPL     10-K  0000320193-20-000096  320193  Apple Inc. (Filer)
#
#   companyName                                linkToFilingDetails  \
# 0  Apple Inc.  https://www.sec.gov/Archives/edgar/data/320193...
# 1  Apple Inc.  https://www.sec.gov/Archives/edgar/data/320193...
# 2  Apple Inc.  https://www.sec.gov/Archives/edgar/data/320193...
# 3  Apple Inc.  https://www.sec.gov/Archives/edgar/data/320193...
# 4  Apple Inc.  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                          description  \
# 0  Form 10-K - Annual report [Section 13 and 15(d...
# 1  Form 10-K - Annual report [Section 13 and 15(d...
# 2  Form 10-K - Annual report [Section 13 and 15(d...
# 3  Form 10-K - Annual report [Section 13 and 15(d...
# 4  Form 10-K - Annual report [Section 13 and 15(d...
#
#                                            linkToTxt  \
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
#                      filedAt  \
# 0  2024-11-01T06:01:36-04:00
# 1  2023-11-02T18:08:27-04:00
# 2  2022-10-27T18:01:14-04:00
# 3  2021-10-28T18:04:28-04:00
# 4  2020-10-29T18:06:25-04:00
#
#                                  documentFormatFiles periodOfReport  \
# 0  [{'sequence': '1', 'size': '1503780', 'documen...     2024-09-28
# 1  [{'sequence': '1', 'size': '1558924', 'documen...     2023-09-30
# 2  [{'sequence': '1', 'size': '2049857', 'documen...     2022-09-24
# 3  [{'sequence': '1', 'size': '2051190', 'documen...     2021-09-25
# 4  [{'sequence': '1', 'size': '2467306', 'documen...     2020-09-26
#
#                                             entities  \
# 0  [{'fiscalYearEnd': '0928', 'stateOfIncorporati...
# 1  [{'fiscalYearEnd': '0930', 'stateOfIncorporati...
# 2  [{'fiscalYearEnd': '0924', 'stateOfIncorporati...
# 3  [{'fiscalYearEnd': '0925', 'stateOfIncorporati...
# 4  [{'fiscalYearEnd': '0926', 'stateOfIncorporati...
#
#                                  id seriesAndClassesContractsInformation  \
# 0  de98dc75c98b80c2bbfeb8d07503354b                                   []
# 1  0de409aa5047085970060a9efa218f8b                                   []
# 2  9b58a0b3d70dc9de06bdf3d560b3317a                                   []
# 3  3249304e3a3d5edb2caddaba70628064                                   []
# 4  96618433ccb8db908723fb09aa081a34                                   []
#
#                                           linkToHtml linkToXbrl  \
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                            dataFiles effectivenessDate
# 0  [{'sequence': '14', 'size': '58200', 'document...               NaN
# 1  [{'sequence': '8', 'size': '59730', 'documentU...               NaN
# 2  [{'sequence': '8', 'size': '58100', 'documentU...               NaN
# 3  [{'sequence': '8', 'size': '60123', 'documentU...        2021-09-25
# 4  [{'sequence': '10', 'size': '64821', 'document...               NaN

# %%
urls = filings[['ticker',
                'formType',
                'periodOfReport',
                'filedAt',
                'linkToFilingDetails']].rename(columns={'linkToFilingDetails': 'filingUrl'})

urls['financialReportsUrl'] = urls['filingUrl'].apply(lambda url: '/'.join(url.split('/')[:-1]) + '/Financial_Report.xlsx')

urls.head(10)
# Out:
#   ticker formType periodOfReport                    filedAt  \
# 0   AAPL     10-K     2024-09-28  2024-11-01T06:01:36-04:00
# 1   AAPL     10-K     2023-09-30  2023-11-02T18:08:27-04:00
# 2   AAPL     10-K     2022-09-24  2022-10-27T18:01:14-04:00
# 3   AAPL     10-K     2021-09-25  2021-10-28T18:04:28-04:00
# 4   AAPL     10-K     2020-09-26  2020-10-29T18:06:25-04:00
#
#                                            filingUrl  \
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...
#
#                                  financialReportsUrl
# 0  https://www.sec.gov/Archives/edgar/data/320193...
# 1  https://www.sec.gov/Archives/edgar/data/320193...
# 2  https://www.sec.gov/Archives/edgar/data/320193...
# 3  https://www.sec.gov/Archives/edgar/data/320193...
# 4  https://www.sec.gov/Archives/edgar/data/320193...

# %%
#Download Financial_reports.xlsx of All EDGAR Filings
import os, requests

folder_path = './reports'

if not os.path.exists(folder_path):
  os.makedirs(folder_path)


def download_report(filing):
  reports_path = filing['financialReportsUrl'].replace('https://www.sec.gov/Archives/edgar/data/', '')
  base_url = 'https://archive.sec-api.io/' + reports_path
  render_api_url = base_url + '?token=' + API_KEY

  response = requests.get(render_api_url)

  file_name = f"{filing['ticker']}-{filing['periodOfReport']}-{filing['formType']}.xlsx"
  file_path = f"{folder_path}/{file_name}"

  output = open(file_path, 'wb')
  output.write(response.content)
  output.close()

# %%
#!pip install -q pandarallel

from pandarallel import pandarallel
number_of_workers = 4
pandarallel.initialize(progress_bar=True, nb_workers=number_of_workers, verbose=0)

# %%
urls.parallel_apply(download_report, axis=1)
print(f"Downloaded {len(urls)} reports")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 urls.parallel_apply(download_report, axis=1)
#       2 print(f"Downloaded {len(urls)} reports")
#
# File c:\Users\Dafa_1\venv\Lib\site-packages\pandarallel\core.py:394, in parallelize_with_pipe.<locals>.closure(data, user_defined_function, *user_defined_function_args, **user_defined_function_kwargs)
#     390 reduce_extra = data_type.get_reduce_extra(data, user_defined_function_kwargs)
#     392 show_progress_bars = progress_bars_type != ProgressBarsType.No
# --> 394 progress_bars = get_progress_bars(progresses_length, show_progress_bars)
#     395 progresses = [0] * nb_workers
#     396 workers_status = [WorkerStatus.Running] * nb_workers
#
# File c:\Users\Dafa_1\venv\Lib\site-packages\pandarallel\progress_bars.py:179, in get_progress_bars(maxs, show)
#     175 def get_progress_bars(
#     176     maxs: List[int], show
#     177 ) -> Union[ProgressBarsNotebookLab, ProgressBarsConsole]:
#     178     return (
# --> 179         ProgressBarsNotebookLab(maxs, show)
#     180         if is_notebook_lab()
#     181         else ProgressBarsConsole(maxs, show)
#     182     )
#
# File c:\Users\Dafa_1\venv\Lib\site-packages\pandarallel\progress_bars.py:133, in ProgressBarsNotebookLab.__init__(self, maxs, show)
#     130     return
#     132 from IPython.display import display
# --> 133 from ipywidgets import HBox, IntProgress, Label, VBox
#     135 self.__bars = [
#     136     HBox(
#     137         [
#    (...)    142     for max in maxs
#     143 ]
#     145 display(VBox(self.__bars))
#
# ModuleNotFoundError: No module named 'ipywidgets'
